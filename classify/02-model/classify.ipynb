# %%
from fastai2.text.all import *

# %%
import socket
path = '/home/mreishus/Sync/sbin/classify/01-get-data/data'
if socket.gethostname() == 'atlas':
    path = '/home/mmr/Sync/sbin/classify/01-get-data/data'

# %%
# Use all extensions:
# tokenize_folder(path, [])
# This works, but TextDataLoaders.from_folders I can't get
# to work with all extensions.
tokenize_folder(path)

# %%
dls = TextDataLoaders.from_folder(path, valid_pct=0.15, extensions=[], bs=64)

# %%
dls.show_batch(max_n=4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos # frozen_string_literal : true \n\n require " cgi " \n require " action_view / helpers / xxunk " \n require " action_view / helpers / tag_helper " \n require " action_view / helpers / xxunk " \n require " action_view / helpers / xxunk " \n require " action_view / xxunk " \n require " action_view / xxunk " \n require " active_support / core_ext / module / attribute_accessors " \n require " active_support / core_ext / hash / slice " \n require " active_support / core_ext / string / output_safety " \n require " active_support / core_ext / string / inflections " \n\n module actionview \n▁ # = xxmaj action xxmaj view xxmaj form xxmaj helpers \n▁ module xxmaj helpers # : nodoc : \n▁ # xxmaj form helpers are designed to make working with resources much easier \n▁ # compared to using vanilla xxup html . \n▁</td>
#       <td>ruby</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>xxbos / / xxmaj package staticcheck contains a linter for xxmaj go source code . \n package staticcheck / / import " honnef.co / go / tools / staticcheck " \n\n import ( \n\t " fmt " \n\t " go / ast " \n\t " go / constant " \n\t " go / token " \n\t " go / types " \n\t xxunk " html / template " \n\t " net / http " \n\t " reflect " \n\t " regexp " \n\t " regexp / syntax " \n\t " sort " \n\t " strconv " \n\t " strings " \n\t xxunk " text / template " \n\t " unicode " \n\n\t . " honnef.co / go / tools / arg " \n\t " honnef.co / go / tools / deprecated " \n\t " honnef.co / go / tools / facts " \n\t " honnef.co / go / tools /</td>
#       <td>go</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>xxbos / / go run mksyscall.go -tags linux , ppc64 syscall_linux.go xxunk \n▁ / / xxmaj code generated by the command above ; see readme.md . xxup do xxup not xxup edit . \n\n▁ / / + build linux , ppc64 \n\n package unix \n\n import ( \n\t " syscall " \n\t " unsafe " \n ) \n\n var _ syscall.errno \n\n▁ / / xxup this xxup file xxup is xxup generated xxup by xxup the xxup command xxup at xxup the xxup top ; xxup do xxup not xxup edit \n\n func fanotifyinit(flags uint , event_f_flags uint ) ( fd int , err error ) { \n\t r0 , _ , e1 : = syscall(sys_fanotify_init , uintptr(flags ) , uintptr(event_f_flags ) , 0 ) \n\t fd = int(r0 ) \n\t if e1 ! = 0 { \n\t\t err = errnoerr(e1 ) \n\t } \n\t return \n } \n\n▁ /</td>
#       <td>go</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>xxbos / / go run mksyscall.go -l32 -arm -tags linux , mipsle syscall_linux.go xxunk \n▁ / / xxmaj code generated by the command above ; see readme.md . xxup do xxup not xxup edit . \n\n▁ / / + build linux , mipsle \n\n package unix \n\n import ( \n\t " syscall " \n\t " unsafe " \n ) \n\n var _ syscall.errno \n\n▁ / / xxup this xxup file xxup is xxup generated xxup by xxup the xxup command xxup at xxup the xxup top ; xxup do xxup not xxup edit \n\n func fanotifyinit(flags uint , event_f_flags uint ) ( fd int , err error ) { \n\t r0 , _ , e1 : = syscall(sys_fanotify_init , uintptr(flags ) , uintptr(event_f_flags ) , 0 ) \n\t fd = int(r0 ) \n\t if e1 ! = 0 { \n\t\t err = errnoerr(e1 ) \n\t } \n\t return \n }</td>
#       <td>go</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn = language_model_learner(
#    dls, AWD_LSTM, drop_mult=0.3, 
#    metrics=[accuracy, Perplexity()]).to_fp16()

#learn = language_model_learner(
#    dls, AWD_LSTM, drop_mult=0.3, 
#    metrics=[accuracy, Perplexity()])

#learn = text_classifier_learner(dls, AWD_LSTM, metrics=[accuracy, Perplexity()])



learn = text_classifier_learner(dls, AWD_LSTM, drop_mult=0.5, 
                                metrics=accuracy).to_fp16()

# %%
learn.fit_one_cycle(1, 2e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.508912</td>
#       <td>0.123037</td>
#       <td>0.965744</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(1, slice(1e-2/(2.6**4),1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.256245</td>
#       <td>0.079065</td>
#       <td>0.985507</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.freeze_to(-3)
learn.fit_one_cycle(1, slice(5e-3/(2.6**4),5e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.118260</td>
#       <td>0.065997</td>
#       <td>0.981555</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export()

# %%
model_here = os.path.join(path, 'export.pkl')
model_there = os.path.join(path, '..', '..', '03-web', 'export.pkl')
os.rename(model_here, model_there)
